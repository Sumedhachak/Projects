# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumedhachak/Projects/blob/main/image_analysis_using_Matplotlib_and_OpenCV_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing required libraries of opencv 
import cv2 

# importing library for plotting 
from matplotlib import pyplot as plt 

# reads an input image 
img = cv2.imread('/content/OpenCV-Python-image2-Histogram.png',0) 

# find frequency of pixels in range 0-255 
histr = cv2.calcHist([img],[0],None,[256],[0,256]) 

# show the plotting graph of an image 
plt.plot(histr) 
plt.show()

# %%
# alternative way to find histogram of an image 
plt.hist(img.ravel(),256,[0,256]) 
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
